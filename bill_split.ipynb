# %%
import numpy as np
from operator import itemgetter

# %%
Clothes -100 -100 300 -100

# %%
with open('values.dat','r') as file:
    for line in file:
        print(line.strip())
# Out:
# Type Person1 Person2 Person3 Person4
# Cab 400 -100 -100 -200
# Food -250 400 -200 50

# %%
file = open('values.dat','r')
line = []
for i in file:
    line.append(i.split(' ')[:-1])
# for i in range(len(line)-1):
#     if line[i+1][1] == 'equal':
#         amount_pp = (float(line[i+1][3]))/len()
#         indx_ = line[0].index(line[i+1][2])
#         new = [line[i+1][0]]
#         for j in range(len(line[i+1])-1):
#             if j+1 == indx_:
#                 new.append(amount)

# %%
All = []
Givers = []
Takers = []
Zeroes = []
for i in range(len(line[0])-1):
    sum = 0
    temp = [row[i+1] for row in line]
    for j in range(len(temp)-1):
        sum += float(temp[j+1])
    All.append([line[0][i+1],sum])
    if sum > 0:
        Takers.append([line[0][i+1],sum])
    if sum<0:
        Givers.append([line[0][i+1],sum])
    else:
        Zeroes.append([line[0][i+1],sum])
        
Givers = sorted(Givers,key=itemgetter(1),reverse=True)
Takers = sorted(Takers,key=itemgetter(1))

# %%
Transaction = []
for i in range(len(Givers)): 
    for j in range(len(Takers)):
        if abs(Givers[i][1]) >= Takers[j][1]:
            option = Takers[j]
            break
    Givers[i][1] += option[1]
    Takers[j][1] -= option[1]

# %%
Givers
# Out:
# [['Person4', 0.0], ['Person3', -300.0]]
